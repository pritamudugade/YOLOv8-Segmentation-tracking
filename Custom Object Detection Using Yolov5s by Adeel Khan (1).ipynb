# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/training_data.zip
# Out:
# Archive:  /content/drive/MyDrive/training_data.zip
#    creating: training_data/images/
#    creating: training_data/images/train/
#   inflating: training_data/images/train/scene00001.jpg
#   inflating: training_data/images/train/scene00005.jpg
#   inflating: training_data/images/train/scene00009.jpg
#   inflating: training_data/images/train/scene00013.jpg
#   inflating: training_data/images/train/scene00017.jpg
#   inflating: training_data/images/train/scene00021.jpg
#   inflating: training_data/images/train/scene00025.jpg
#   inflating: training_data/images/train/scene00029.jpg
#   inflating: training_data/images/train/scene00033.jpg
#   inflating: training_data/images/train/scene00037.jpg
#   inflating: training_data/images/train/scene00041.jpg
#   inflating: training_data/images/train/scene00045.jpg
#   inflating: training_data/images/train/scene00049.jpg
#   inflating: training_data/images/train/scene00053.jpg
#   inflating: training_data/images/train/scene00057.jpg
# ...

# %%
#load yolov5
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.0/78.2 GB disk)

# %%
#training the data
# !python train.py --img 640 --batch 16 --epochs 500 --data custom_data_new.yaml --weights yolov5s.pt  --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data_new.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "/content/yolov5/yolov5/train.py", line 642, in <module>
#     main(opt)
#   File "/content/yolov5/yolov5/train.py", line 506, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/747dfabf-f429-4fd6-8c5c-4fed8ebca012.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/747dfabf-f429-4fd6-8c5c-4fed8ebca012.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/747dfabf-f429-4fd6-8c5c-4fed8ebca012.jpg: 384x640 1 car, 1 number_plate, 39.4ms
# Speed: 0.5ms pre-process, 39.4ms inference, 87.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
